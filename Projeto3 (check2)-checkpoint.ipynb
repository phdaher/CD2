# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 3 - INSPER

# %% [markdown]
# ___
# ## Nome 1 - Augusto Franco de Paula
#
# ## Nome 2 - Gabriel Heusi Pereira Bueno de Camargo
#
# ## Nome 3 - Pedro Henrique Carvalho Daher
#
# ___

# %% [markdown]
# ___
#
# ## INTRODUÇÃO

# %% [markdown]
#         A partir de um interesse sobre carros, o grupo optou por fazer um modelo de previsão dos preços de carros e ainda analisar aqueles considerados "Overpriced", ou seja acima do preço considerado padrão para determinado modelo.
#         A base de dados utilizada para o estudo é de 2017 e avalia apenas carros americanos, dessa forma deve-se explorar esta afim de possibilitar tal modelo de predição. Para isso será importante avaliar quais as variáveis de maior influência sobre o preço de um carro para que ao fim haja uma comparação entre o preço real do carro e seu preço esperado a partir das variáveis que o definem. Por fim a análise de carros acima do preço servirá como dado de eficiência do estudo
#         Dessa forma baseou-se em artigos cientificos e estudos que avaliam os modelos de distribuicão destes preços, entre eles estão:

# %% [markdown]
# ___
# ## MINERANDO DADOS e CARACTERÍSTICAS DO DATASET

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
import os
import math
from sys import stdin
from numpy import arange
import numpy as np
import seaborn as sns

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
data = pd.read_csv('data.csv')
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Gabriel Camargo\Documents\Insper - Engenharia\Ciência dos Dados - DP\Projeto 3

# %% [markdown]
# ### BASE DE DADOS

# %%
data = shuffle(data)
data.head()
# Out:
#             Make            Model  Year  Engine Fuel Type  Engine HP  \
# 6174         GMC            Jimmy  2000  regular unleaded      190.0
# 7099       Mazda             MX-3  1995  regular unleaded       88.0
# 5837   Chevrolet           Impala  2016  regular unleaded      195.0
# 10851     Nissan            Truck  1995  regular unleaded      134.0
# 4141    Cadillac  Escalade Hybrid  2011  regular unleaded      332.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 6174                6.0           UNKNOWN   four wheel drive              2.0
# 7099                4.0            MANUAL  front wheel drive              2.0
# 5837                4.0         AUTOMATIC  front wheel drive              4.0
# 10851               4.0            MANUAL   four wheel drive              2.0
# 4141                8.0         AUTOMATIC   rear wheel drive              4.0
#
#       Market Category Vehicle Size        Vehicle Style  highway MPG  \
# 6174              NaN      Compact              2dr SUV           18
# 7099        Hatchback      Compact        2dr Hatchback           34
# 5837              NaN        Large                Sedan           31
# 10851             NaN      Compact  Extended Cab Pickup           19
# 4141    Luxury,Hybrid        Large              4dr SUV           23
#
#        city mpg  Popularity   MSRP
# 6174         14         549   2578
# 7099         25         586   2000
# 5837         22        1385  27095
# 10851        16        2009   2281
# 4141         20        1624  74135

# %%
sns.heatmap(data.corr(), annot=True, fmt=".2f")
plt.show()

# %% [markdown]
# A partir do mapa mostrado acima é possível identificar a influência (correlação) de uma variável sobre o preço de um carro. Dessa forma basta analisar e perceber que as três que apresentam maior proporcionalidade são: Ano de fabricação (Year), Potência do Motor (Engine HP) e número de cilindros (Engine Cylinders). Vale lembrar que isto era esperado, afinal essa ferramenta só é capaz de comparar dados quantitativos.

# %% [markdown]
# ### Análise Descritiva

# %% [markdown]
# A partir desta seção será reavaliada a ideia das variáveis e sua distribuição de acordo com o preço. Como por exemplo a "Engine Cylinders" será categorizado como uma espécie de força fornecida pelos cilindros ao carro e ainda observar onde a predominância do preço dos carros, separando em faixas de valor de compra/venda.

# %%
#data.loc[(data['Engine Cylinders']>0) & (data['Engine Cylinders']<2),"Força_dos_Cilindros"] = "Fraco"
#data.loc[(data['Engine Cylinders']>=2) & (data['Engine Cylinders']<=4),"Força_dos_Cilindros"] = "Médio"
#data.loc[(data['Engine Cylinders']>=6) & (data['Engine Cylinders']<8),"Força_dos_Cilindros"] = "Forte"
#data.loc[(data['Engine Cylinders']>=8) & (data['Engine Cylinders']<=12),"Força_dos_Cilindros"] = "Muito Forte"
data = data.loc[data.MSRP<125000,['Year','Engine HP','Engine Cylinders','MSRP']]
data.columns=["Ano","Potência","Número_de_Cilindros","Price"]
print(data.Price.describe())
print()
print(data.head())
# Out:
# count     11416.000000
# mean      31474.899615
# std       20587.012094
# min        2000.000000
# 25%       20525.000000
# 50%       29280.000000
# 75%       40096.250000
# max      124900.000000
# Name: Price, dtype: float64
#
#         Ano  Potência  Número_de_Cilindros  Price
# 6174   2000     190.0                  6.0   2578
# 7099   1995      88.0                  4.0   2000
# 5837   2016     195.0                  4.0  27095
# 10851  1995     134.0                  4.0   2281
# 4141   2011     332.0                  8.0  74135

# %%
data.head()
# Out:
#         Ano  Potência  Número_de_Cilindros  Price
# 6174   2000     190.0                  6.0   2578
# 7099   1995      88.0                  4.0   2000
# 5837   2016     195.0                  4.0  27095
# 10851  1995     134.0                  4.0   2281
# 4141   2011     332.0                  8.0  74135

# %%
data.Price.describe()
# Out:
# count     11416.000000
# mean      31474.899615
# std       20587.012094
# min        2000.000000
# 25%       20525.000000
# 50%       29280.000000
# 75%       40096.250000
# max      124900.000000
# Name: Price, dtype: float64

# %%
faixa = range(5000,80000,3000)
price = pd.cut(data.Price, bins=faixa)
price.value_counts(sort=False, normalize=True)*100
# Out:
# (5000, 8000]       0.299081
# (8000, 11000]      0.224311
# (11000, 14000]     0.822474
# (14000, 17000]     4.411451
# (17000, 20000]     5.981628
# (20000, 23000]     9.346294
# (23000, 26000]    11.130100
# (26000, 29000]    10.585345
# (29000, 32000]    10.745567
# (32000, 35000]     8.673360
# (35000, 38000]     7.562487
# (38000, 41000]     6.163213
# (41000, 44000]     5.351421
# (44000, 47000]     4.026917
# (47000, 50000]     3.375347
# (50000, 53000]     2.542192
# (53000, 56000]     1.997436
# (56000, 59000]     1.228370
# (59000, 62000]     1.367229
# (62000, 65000]     1.452681
# (65000, 68000]     0.950652
# (68000, 71000]     0.737022
# (71000, 74000]     0.437941
# (74000, 77000]     0.587481
# Name: Price, dtype: float64

# %%
plot = data.Price.plot.hist(bins=faixa,title='Histograma de Distribuição do Preço dos Carros (H1)', figsize=(6, 6), alpha=0.9)
plt.show()

# %% [markdown]
# ___
# ## MODELOS DE PREDIÇÃO

# %% [markdown]
# [O tópico C.PROCESSO E ESTATÍSTICAS DE VALIDAÇÃO estará dentro deste tópico. Organize-o aqui de forma clara!]
#
# [ORGANIZE AQUI TODOS OS MODELOS DE PREDIÇÃO NECESSÁRIOS NESTE PROJETO!]

# %% [markdown]
# o MODELO DE PREDIÇÃO PELA MÉDIA
#
# o MODELO DOS K VIZINHOS MAIS PRÓXIMOS (K-Nearest Neighbors Regression)
#
# o MODELO DE REGRESSÃO LINEAR (Multiple Linear Regression)
#
# o MODELO DE ÁRVORES DE REGRESSÃO (Decision Tree Regression)

# %%
#PE=[]
#PR=[]
#b=0
#c=0
#for a in range(len(data)):
       # PE.append((data.Price[a])-(data['Price'].mean()))
        #PR.append((data.Price[a]))
#scatter_plot = plt.scatter(PE,PR,color="red",alpha=0.15)
#plt.title("Avaliação em escala logaritmica de Preço Estimado x Preço Real (G1)")
#plt.xlabel("Preço Estimado (Ln $)")
#plt.ylabel("Preço Real (Ln $)")
#plt.plot()
#plt.show()

# %%
print((data.Price[0])-31474.899615)
# Out:
# 14660.100385

# %%
from IPython.display import HTML, display
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.sandbox.regression.predstd import wls_prediction_std
#pricing_model = ols("Price ~ Ano + Potência + Número_de_Cilindros", data=data).fit()
pricing_model_summary = pricing_model.summary()
HTML(
(pricing_model_summary
    .as_html()
    .replace('<th>  Adj. R-squared:    </th>', '<th style="background-color:#aec7e8;"> Adj. R-squared: </th>')
    .replace('<th>coef</th>', '<th style="background-color:#ffbb78;">coef</th>')
    .replace('<th>std err</th>', '<th style="background-color:#c7e9c0;">std err</th>')
    .replace('<th>P>|t|</th>', '<th style="background-color:#bcbddc;">P>|t|</th>')
    .replace('<th>[0.025</th>    <th>0.975]</th>', '<th style="background-color:#ff9896;">[0.025</th>    <th style="background-color:#ff9896;">0.975]</th>'))
)
# Out:
# <table class="simpletable">
# <caption>OLS Regression Results</caption>
# <tr>
#   <th>Dep. Variable:</th>          <td>Price</td>      <th>  R-squared:         </th>  <td>   0.724</td>
# </tr>
# <tr>
#   <th>Model:</th>                   <td>OLS</td>       <th style="background-color:#aec7e8;"> Adj. R-squared: </th>  <td>   0.724</td>
# </tr>
# <tr>
#   <th>Method:</th>             <td>Least Squares</td>  <th>  F-statistic:       </th>  <td>   9914.</td>
# </tr>
# <tr>
#   <th>Date:</th>             <td>Thu, 24 May 2018</td> <th>  Prob (F-statistic):</th>   <td>  0.00</td>
# </tr>
# <tr>
#   <th>Time:</th>                 <td>15:20:57</td>     <th>  Log-Likelihood:    </th> <td>-1.2117e+05</td>
# </tr>
# <tr>
#   <th>No. Observations:</th>      <td> 11319</td>      <th>  AIC:               </th>  <td>2.424e+05</td>
# </tr>
# <tr>
#   <th>Df Residuals:</th>          <td> 11315</td>      <th>  BIC:               </th>  <td>2.424e+05</td>
# </tr>
# <tr>
#   <th>Df Model:</th>              <td>     3</td>      <th>                     </th>      <td> </td>
# </tr>
# <tr>
#   <th>Covariance Type:</th>      <td>nonrobust</td>    <th>                     </th>      <td> </td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#            <td></td>              <th style="background-color:#ffbb78;">coef</th>     <th style="background-color:#c7e9c0;">std err</th>      <th>t</th>      <th style="background-color:#bcbddc;">P>|t|</th> <th>[95.0% Conf. Int.]</th>
# </tr>
# <tr>
#   <th>Intercept</th>           <td>-1.609e+06</td> <td> 3.43e+04</td> <td>  -46.908</td> <td> 0.000</td> <td>-1.68e+06 -1.54e+06</td>
# </tr>
# <tr>
#   <th>Ano</th>                 <td>  800.5553</td> <td>   17.041</td> <td>   46.977</td> <td> 0.000</td> <td>  767.151   833.960</td>
# </tr>
# <tr>
#   <th>Potência</th>            <td>  167.6221</td> <td>    2.036</td> <td>   82.315</td> <td> 0.000</td> <td>  163.631   171.614</td>
# </tr>
# <tr>
#   <th>Número_de_Cilindros</th> <td>-1579.9234</td> <td>  116.952</td> <td>  -13.509</td> <td> 0.000</td> <td>-1809.169 -1350.678</td>
# </tr>
# </table>
# <table class="simpletable">
# <tr>
#   <th>Omnibus:</th>       <td>2880.730</td> <th>  Durbin-Watson:     </th> <td>   1.978</td>
# </tr>
# <tr>
#   <th>Prob(Omnibus):</th>  <td> 0.000</td>  <th>  Jarque-Bera (JB):  </th> <td>13387.490</td>
# </tr>
# <tr>
#   <th>Skew:</th>           <td> 1.164</td>  <th>  Prob(JB):          </th> <td>    0.00</td>
# </tr>
# <tr>
#   <th>Kurtosis:</th>       <td> 7.792</td>  <th>  Cond. No.          </th> <td>6.84e+05</td>
# </tr>
# </table>

# %%
#pricing_model = ols("Price ~ Ano + Potência + Número_de_Cilindros", data=data).fit()
pricing_model.predict()
# Out:
# array([ 14420.79752977,  -3519.59036269,  31227.64005991, ...,
#         42856.09682292,  43333.98942388,  27242.26411162])

# %%
print (pricing_model.params)
# Out:
# Intercept             -1.609058e+06
# Ano                    8.005553e+02
# Potência               1.676221e+02
# Número_de_Cilindros   -1.579923e+03
# dtype: float64

# %%
fig = plt.figure(figsize=(20,10))
fig = sm.graphics.plot_partregress_grid(pricing_model, fig=fig)
plt.show()

# %%
X = data[['Ano','Potência','Número_de_Cilindros']]
X = sm.add_constant(X)

# %%
#PE = pricing_model.predict(X)
#pricing_model = ols("Price ~ Ano + Potência + Número_de_Cilindros", data=data).fit()

# %%
#PR = data.Price 
#scatter_plot = plt.scatter(PE,PR,color="red",alpha=0.15)
#plt.title("Avaliação de Preço Estimado x Preço Real (G1)")
#plt.xlabel("Preço Estimado")
#plt.ylabel("Preço Real")
#plt.plot()
#plt.show()
